# %%
import pandas as pd
import string

# %% [markdown]
# # **Reading Data**

# %%
df1 = pd.read_csv(r'S08_question_answer_pairs.txt',encoding='latin-1',sep='\t')
df2 = pd.read_csv(r'S09_question_answer_pairs.txt',encoding='latin-1',sep='\t')
df3 = pd.read_csv(r'S10_question_answer_pairs.txt',encoding='latin-1',sep='\t')
df = pd.concat([df1,df2,df3],ignore_index=True)
df.head()
# Out:
#       ArticleTitle                                           Question Answer  \
# 0  Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...    yes
# 1  Abraham_Lincoln  Was Abraham Lincoln the sixteenth President of...   Yes.
# 2  Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...    yes
# 3  Abraham_Lincoln  Did Lincoln sign the National Banking Act of 1...   Yes.
# 4  Abraham_Lincoln                   Did his mother die of pneumonia?     no
#
#   DifficultyFromQuestioner DifficultyFromAnswerer  ArticleFile ï»¿ArticleTitle
# 0                     easy                   easy  S08_set3_a4             NaN
# 1                     easy                   easy  S08_set3_a4             NaN
# 2                     easy                 medium  S08_set3_a4             NaN
# 3                     easy                   easy  S08_set3_a4             NaN
# 4                     easy                 medium  S08_set3_a4             NaN

# %%
print("Number of records: ",len(df))
# Out:
# Number of records:  3998

# %% [markdown]
# # **Data Preprocessing- Cleaning**

# %%
df.info()
df = df[['Question','Answer','ArticleFile','DifficultyFromQuestioner','DifficultyFromAnswerer']]
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ArticleTitle              3173 non-null   object
#  1   Question                  3961 non-null   object
#  2   Answer                    3422 non-null   object
#  3   DifficultyFromQuestioner  3043 non-null   object
#  4   DifficultyFromAnswerer    3418 non-null   object
#  5   ArticleFile               3996 non-null   object
#  6   ï»¿ArticleTitle           825 non-null    object
# dtypes: object(7)
# memory usage: 218.8+ KB
#                                             Question Answer  ArticleFile  \
# 0  Was Abraham Lincoln the sixteenth President of...    yes  S08_set3_a4
# 1  Was Abraham Lincoln the sixteenth President of...   Yes.  S08_set3_a4
# 2  Did Lincoln sign the National Banking Act of 1...    yes  S08_set3_a4
# 3  Did Lincoln sign the National Banking Act of 1...   Yes.  S08_set3_a4
# 4                   Did his mother die of pneumonia?     no  S08_set3_a4
#
#   DifficultyFromQuestioner DifficultyFromAnswerer
# 0                     easy                   easy
# 1                     easy                   easy
# 2                     easy                 medium
# 3                     easy                   easy
# 4                     easy                 medium

# %%
print(f"Number of duplicate questions: {len(df) - df['Question'].nunique()}")

df.drop_duplicates(subset=['Question'],inplace=True)
print("\nNumber of records after removing duplicates: ",len(df))
# Out:
# Number of duplicate questions: 1542
#
# Number of records after removing duplicates:  2457

# %%
# Checking null values and removing them
df.isnull().sum()
# Out:
# Question                      1
# Answer                      272
# ArticleFile                   2
# DifficultyFromQuestioner    892
# DifficultyFromAnswerer      277
# dtype: int64

# %%
df.dropna(subset=['Question'],inplace=True)
df.dropna(subset=['Answer'],inplace=True)
df.dropna(subset=['ArticleFile'],inplace=True)
df.dropna(subset=['DifficultyFromQuestioner'],inplace=True)
df.dropna(subset=['DifficultyFromAnswerer'],inplace=True)
df.reset_index(drop=True,inplace=True)
print("Number of records after removing blanks: ",len(df))
# Out:
# Number of records after removing blanks:  1507

# %%
def format_column(text):
    text = text.lower()
    text = text.translate(str.maketrans('','',string.punctuation)) # remove punctuations
    return text

df['Answer'] = df.loc[:,'Answer'].apply(lambda x:format_column(x))
df.head()
# Out:
#                                             Question     Answer  ArticleFile  \
# 0  Was Abraham Lincoln the sixteenth President of...        yes  S08_set3_a4
# 1  Did Lincoln sign the National Banking Act of 1...        yes  S08_set3_a4
# 2                   Did his mother die of pneumonia?         no  S08_set3_a4
# 3      How many long was Lincoln's formal education?  18 months  S08_set3_a4
# 4       When did Lincoln begin his political career?       1832  S08_set3_a4
#
#   DifficultyFromQuestioner DifficultyFromAnswerer
# 0                     easy                   easy
# 1                     easy                 medium
# 2                     easy                 medium
# 3                   medium                   easy
# 4                   medium                   easy

# %%
dfc=df
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1507 entries, 0 to 1506
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Question                  1507 non-null   object
#  1   Answer                    1507 non-null   object
#  2   ArticleFile               1507 non-null   object
#  3   DifficultyFromQuestioner  1507 non-null   object
#  4   DifficultyFromAnswerer    1507 non-null   object
# dtypes: object(5)
# memory usage: 59.0+ KB

# %% [markdown]
# # **Topic Modelling**

# %%
import spacy
spacy.load('en_core_web_sm')
from spacy.lang.en import English
parser = English()
def tokenize(text):
    lda_tokens = []
    tokens = parser(text)
    for token in tokens:
        if token.orth_.isspace():
            continue
        else:
            lda_tokens.append(token.lower_)
    return lda_tokens
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet as wn
def get_lemma(word):
    lemma = wn.morphy(word)
    if lemma is None:
        return word
    else:
        return lemma

from nltk.stem.wordnet import WordNetLemmatizer
def get_lemma2(word):
    return WordNetLemmatizer().lemmatize(word)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def prepare_text_for_lda(text):
    tokens = tokenize(text)
    tokens = [token for token in tokens if len(token) > 4] #include the token only if it's length is greater than 4
    tokens = [token for token in tokens if token not in en_stop] #include if token is not a stopword
    tokens = [get_lemma(token) for token in tokens] #lematizing each word in the token list
    return tokens
#preparing the text for topic modelling

# %% [markdown]
# **Seperating the Questions form the database**

# %%
selected_column=df['Question']
output_csv_file='QuestionForTopicDetection.csv'
selected_column.to_csv(output_csv_file, index=False, header=True)

# %%
#Run this only to get the lemma for all the Questions
import random
text_data = []
# count=0
with open('QuestionForTopicDetection.csv') as f:
    for line in f:
        tokens = prepare_text_for_lda(line)
        print(tokens)
        text_data.append(tokens)
        # count+=1
# print(count)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['question']
# ['abraham', 'lincoln', 'sixteenth', 'president', 'unite', 'state']
# ['lincoln', 'national', 'banking']
# ['mother', 'pneumonia']
# ['lincoln', 'formal', 'education']
# ['lincoln', 'begin', 'political', 'career']
# ['legal', 'tender', 'establish']
# ['suggest', 'lincoln', 'beard']
# ['gettysburg', 'address', 'argue', 'america']
# ['lincoln', 'breckinridge', 'election']
# ['abraham', 'lincoln', 'first', 'president', 'unite', 'state']
# ['lincoln', 'start', 'political', 'career']
# ['lincoln', 'represent', 'alton', 'sangamon', 'railroad']
# ['county', 'lincoln']
# ['lincoln', 'first', 'serve', 'president']
# ['assassinate', 'lincoln']
# ['lincoln', 'election']
# ['general', 'charge', 'battle', 'antietam']
# ['lincoln', 'issue', 'emancipation', 'proclamation']
# ['beetle', 'insect']
# ['beetle', 'found', 'polar', 'region']
# ['beetle', 'antenna', 'function', 'primarily', 'organs', 'smell']
# ['three', 'section', 'beetle']
# ['defense', 'mechanism', 'colour', 'shape', 'deceive', 'potential', 'enemy']
# ['beetle', 'potato', 'plant']
# ['beetle', 'larva', 'differentiate', 'insect', 'larva']
# ['beetle']
# ['similarity', 'beetle', 'grasshopper']
# ['certain', 'species', 'beetle', 'consider', 'pest']
# ['beetle', 'general', 'anatomy', 'uniform']
# ['beetle', 'endopterygotes']
# ['species', 'beetle']
# ['sperm', 'cell', 'transfer', 'female']
# ['study', 'beetle', 'call']
# ['possible', '350,000', 'species', 'beetle']
# ['adephaga', 'suborder', 'larger', 'polyphaga', 'suborder']
# ['carrion', 'beetle']
# ['calvin', 'coolidge', 'twenty', 'ninth', 'president']
# ['calvin', 'coolidge', 'plymouth', 'windsor', 'county', 'vermont']
# ['coolidge', 'graduate', 'black', 'river', 'academy']
# []
# ['coolidge', 'marry', 'grace', 'goodhue']
# ['period', 'rapid', 'economic', 'growth', 'unite', 'state', 'experience', 'coolidge', 'presidency']
# ['coolidge', 'graduate', 'amherst']
# ['state', 'coolidge', 'governor']
# ['appoint', 'harlan', 'fiske', 'stone', 'supreme', 'court']
# ['coolidge', 'thirteenth', 'president', 'unite', 'state']
# ['calvin', 'coolidge', 'republican']
# ['calvin', 'coolidge', 'governor', 'massachus08_setts']
# ['coolidge']
# ['coolidge', 'grandfather', 'government', 'office']
# ['state', 'coolidge']
# ['calvin', 'older', 'coolidge']
# ['coolidge', 'amherst', 'college']
# ['cause', 'calvin', 'death']
# ['calvin', 'coolidge', 'vega']
# ['coolidge', 'oppose', 'republican', 'nomination', 'governor', 'massachus08_setts']
# ['coolidge', 'marry', 'grace', 'goodhue']
# ['coolidge', 'office']
# ['fraternity', 'coolidge', 'member']
# ['coolidge', 'married']
# ['coolidge', 'attend', 'school']
# ['president', 'visit']
# ['years', 'coolidge']
# ['france', 'nearly', 'colony', 'europe']
# ['canada', 'member']
# ['canada', 'official', 'language']
# ['significant', 'official', 'language']
# ['addition', 'royal', 'samuel', 'champlain', 'establish', 's08_settlement']
# ['consitution', 'formerly', 'call']
# ['country', 'establish', 'colony', 'canada']
# ['canada', 'help', 'peacekeeping', 'effort']
# ['percentage', 'population', 'speak', 'english', 'french']
# ['canada', 'bilingual']
# ['canadian', 'soldier', 'battle', 'ridge']
# ['official', 'language', 'canada', 'german']
# ['province', 'territory', 'canada']
# ['canada', 'national', 'unemployment']
# ['densely', 'populate', 'canada']
# ['large', 'country', 'world']
# ['large', 'religious', 'group', 'canada']
# ['canada', 'large', 'arm', 'force', 'world']
# ['duck', 'arctic', 'northern', 'hemisphere', 'migratory']
# ['drake']
# ['duck', 'quack']
# ['specialize', 'species', 'adapt', 'catch', 'large']
# ['animal', 'attract', 'humor', 'silliness']
# ['economic']
# ['daffy']
# ['make', 'difficult', 'diving']
# ['reason', 'hunting', 'duck']
# ['duck', 'forage', 'underwater']
# ['often', 'duck']
# ['economic', 'duck']
# ['duck']
# ['unrelated', 'water', 'bird', 'duck', 'sometimes', 'confuse']
# []
# ['common', 'predator', 'duck']
# ['mallard', 'tongue']
# ['diving', 'duck', 'heavy', 'dabble', 'duck']
# ['adult', 'duck', 'flier']
# ['duck', 'accept', 'presence', 'populate', 'area']
# ['type', 'unrelated', 'water', 'bird', 'similar', 'form', 'duck', 'sometimes', 'confuse']
# ['duckling', 'particularly', 'vulnerable']
# ['economic']
# ['allow', 'filter', 'water', 'beak', 'inside']
# ['expression', 'conceptual', 'framework', 'testing', 'computer', 'system']
# ['expression', 'sitting']
# ['egypt', 'border', 'strip']
# ['egypt', 'populate', 'country', 'africa']
# ['egypt', 'political', 'influence', 'middle']
# []
# ['religion', 'egypt', 'outlaw']
# ['poulation', 'egypt']
# ['egypt', 'population']
# ['large', 'number', 'living', 'egypt', 'today']
# ['period', 'akhenaten', 'pharaoh']
# ['egypt']
# ['egypt', 'receive', 'least', 'rainfall', 'world']
# ['egypt', 'foreign', 'policy', 'operate', 'along', 'moderate', 'line']
# ['since', 'egypt', 'republic']
# ['great', 'sphinx', 'pyramid', 'build']
# ['country', 'border', 'egypt']
# ['estimate', 'population', 'egypt']
# ['egypt']
# ['organize', 'agriculture', 'appear', 'valley']
# ['elephant', 'large', 'animal', 'alive', 'today']
# ['elephant', 'rhinoceros']
# ['elephant', 'swimmer']
# ['living', 'species', 'african', 'elephant']
# ['elephant']
# ['phrase', 'elephant', 'never', 'forget', 'metaphorical', 'meaning']
# ['living', 'species', 'asian', 'elephant']
# ['elephant', 'weight', 'birth']
# ['aristotle', 'elephant']
# ['elephant', 'population', 'africa', 'generally', 'small', 'fragment']
# ['asian', 'elephant', 'larger', 'african']
# ['elephant', 'tough']
# ['elephant', 'communicate', 'distance']
# ['african', 'elephant']
# ['elephant', 'gestation', 'period']
# ['species', 'african', 'elephant', 'propose']
# ['elephant', 'important']
# ['animal', 'large', 'brain']
# ['elephant', 'mammal']
# ['elephant', 'working', 'animal']
# ['prefer', 'forest', 'area']
# ['world', 'population', 'asian', 'elephant']
# ['elephant', 'important', 'temperature', 'regulation']
# ['large', 'elephant', 'record']
# ['asian', 'elephant', 'smaller', 'african', 'elephant']
# ['animal', 'larger', 'elephant']
# ['tusklessness', 'become', 'abnormality']
# ['treaty', 'sign', 'ukraine']
# ['finnish', 'member', 'baltic', 'finnic', 'subgroup', 'uralic', 'language']
# ['newspaper', 'finland', 'taloussanomat']
# ['russian', 'general', 'conquer', 'finland']
# ['expectancy', 'finland']
# ['game', 'olympiad']
# ['water', 'south', 'finland']
# ['animal', 'growing', 'number', 'recent', 'conservation', 'effort']
# ['today', 'phone', 'subscription', 'people', 'finland']
# ['matti', 'vanhanen', 'prime', 'minister', 'finland']
# ['capital']
# ['border', 'norway']
# ['expectancy']
# ['big', 'finland']
# ['popular', 'group', 'finland']
# ['finland', 'economy']
# ['finland', 'locate']
# ['weather', 'summer']
# ['salmon', 'remain', 'favorite', 'enthusiast']
# ['cathedral', 'scatter', 'across', 'finland']
# ['accord', 'reader', 'digest', 'finland', 'living']
# ['first', 'verifiable', 'write', 'document', 'appear']
# ['capital']
# ['extensively', 'celebrate', 'holiday']
# ['large', 'proportion', 'population', 'speak', 'swedish', 'mother', 'tongue']
# ['woman', 'longer']
# ['country', 'finland', 'involve', 'international', 'conflict']
# ['member', 'house', 'representative']
# ['member', 'house', 'representative']
# ['gerald', 'member', 'delta', 'kappa', 'epsilon']
# ['award', 'call', 'congressman', 'congressman']
# ['attend', 'university', 'michigan']
# ['position', 'play', 'school', 'football']
# ['biological', 'father']
# ['nominate', 'president']
# ['married']
# ['relate', 'assassination', 'kennedy']
# ['gerald', 'president', 'unite', 'state']
# ['gerald', 'serve', 'republican', 'minority', 'leader', 'house', 'representative']
# ['eagle', 'scout']
# ['district', 'elect']
# ['eagle', 'scout', 'involve', 'funeral', 'procession']
# ['future', 'heisman', 'trophy', 'winner', 'tackle']
# ['another', 'president', 'eagle', 'scout']
# ['extra', 'college']
# ['president', 'live']
# ['ghana', 'twice', 'caput', 'output', 'poor', 'country', 'africa']
# ['english', 'ghana', 'official', 'language']
# ['dutch', 'build', 'elmina', 'castle']
# ['ghana', 'achieve', 'independence', 'unite', 'kingdom']
# ['region', 'ghana', 'divide']
# ['state', 'ghana']
# ['dominant', 'religion', 'ghana']
# ['subfamily', 'native', 'ghanaian', 'language']
# ['weather', 'volta']
# ['ghana']
# ['english', 'official', 'language']
# ['ghana', 'state', 'agyekum', 'kufuor']
# ['ghana']
# ['kwame', 'nkrumah']
# ['ghana', 'relation', 'present', 'ghana']
# ['make', 'ghana', 'parliament']
# ['european', 'country', 'establish', 'state', 'ghana']
# ['share', 'ancestry', 'domestic']
# ['dark', 'adult']
# ['wolf', 'leave']
# ['kind', 'coat', 'wolf']
# ['wolf', 'scent', 'gland']
# ['wolf', 'weigh']
# ['wolf']
# ['surplus', 'killing']
# ['wolf', 'native', 'north', 'america']
# ['mammal']
# ['teeth', 'weapon']
# ['wolf', 'build', 'stamina']
# ['large', 'population', 'thought', 'found']
# ['genus', 'belong']
# ['wolf']
# ['beneficial', 'alpha', 'male', 'female', 'forcefully', 'prevent', 'wolf', 'mating']
# ['tool', 'biologist', 'capture', 'wolf', 'tag']
# ['forward', 'erect', 'slightly', 'bristle', 'hackles', 'wolf']
# ['grover', 'cleveland']
# ['grover', 'cleveland', 'election']
# ['grover', 'cleveland', 'support', 'woman', 'suffrage']
# ['grover', 'cleveland', 'married']
# ['cleveland']
# ['years', 'cleveland', 'office', 'spanish', 'american']
# ['cleveland', 'opponent', 'counter', 'innocent', 'image']
# ['cleveland']
# ['cleveland', 'cancer', 'surgery', 'public']
# ['grover', 'cleveland', 'twenty', 'seventh', 'president', 'unite', 'state']
# ['grover', 'cleveland', 'honest']
# ['grover', 'cleveland', 'married', 'whitehouse']
# ['elect', 'sheriff', 'erire', 'county']
# []
# ['election', 'grover', 'cleveland']
# ['grover', 'cleveland', 'parent']
# ['child', 'grover', 'cleveland']
# ['javanese', 'large', 'politically', 'dominant', 'ethnic', 'group', 'indonesia']
# ['indonesia', 'monarchy', 'presidential', 'system']
# ['japanese', 'invasion', 'subsequent', 'occupation', 'dutch']
# ['timor', 'secede', 'indonesia']
# ['islam', 'become', 'dominant', 'religion', 'sumatra']
# ['indonesia', 'world', 'hightest', 'level', 'biodiversity']
# ['indonesia', 'name', 'become', 'independent', 'country']
# ['indonesia', 'break', 'relations', 'people', 'republic', 'china']
# ['spice', 'originally', 'attract', 'european', 'indonesia']
# ['james', 'monrow', 'fifth', 'president']
# ['first']
# ['first', 'number']
# ['monroe', 'presidency', 'expire']
# ['monroe', 'father']
# ['monroe', 'daughter']
# ['feelings', 'refer']
# ['monroe', 'wedding', 'happen', 'trinity', 'church']
# ['monroe', 'doctrine']
# ['james', 'monroe', 'president', 'unite', 'state']
# ['james', 'monroe', 'attend', 'college', 'william']
# ['james', 'monroe', 'fight', 'continental']
# ['james', 'monroe']
# ['james', 'monroe']
# ['james', 'monroe', 'marry']
# ['james', 'monroe', 'elect', 'governor']
# ['years', 'monroe', 'elect', 'president']
# ['monroe', 'standing', 'behind', 'painting', 'washington', 'crossing', 'delaware']
# ['james', 'monroe', 'appoint', 'secretary']
# ['james', 'monroe']
# ['james', 'monroe', 'graduate', 'william']
# ['james', 'monroe', 'elect', 'president']
# ['property', 'james', 'monroe']
# ['james', 'monroe', 'introduce', 'monroe', 'doctrine']
# ['james', 'monroe']
# ['james', 'monroe', 'letters', 'contain']
# ['result', 'rejection', 'treaty']
# ['adams', 'represent', 'continental', 'congress', 'europe']
# ['adams', 'raise', 'congregationalist']
# ['adams', 'opponent', 'stamp']
# ['adams', 'graduate', 'college']
# ['committee', 'adams', 'draft', 'declaration', 'independence']
# ['jefferson', 'adams']
# ['adams', 'political', 'party']
# ['adams', 'first', 'introduce', 'bicameral', 'legislature']
# ['adams', 'along', 'alexander', 'hamilton']
# ['adams', 'harvard']
# ['adams', 'support', 'stamp']
# ['adams', 'birthplace', 'national']
# ['adams', 'serve', 'president']
# ['party', 'adams', 'presidency']
# ['adams', 'bury']
# ['midnight', 'judges']
# ['adams', 'oppose', 'anderw', 'hamilton']
# ['information', 'record', 'diary']
# ['kangaroo', 'reptile']
# ['kangaroo', 'australian']
# ['james', 'first', 'record', 'kangooroo']
# ['collective', 'kangaroo']
# ['joeys', 'complete', 'postnatal', 'development']
# ['kangaroo', 'crawl', 'walking']
# ['kangaroo']
# ['responsible', 'convert', 'hydrogen', 'byproduct', 'fermentation', 'acetate']
# ['kangaroo']
# ['kangaroo', 'fare', 'since', 'european', 's08_settlement']
# ['kangaroo', 'natural', 'predator']
# ['average', 'expectancy', 'kangaroo']
# ['first', 'official', 'report', 'kangaroo', 'blindness', 'place']
# ['vehicle', 'frequent', 'isolate', 'roads', 'often', 'fit']
# ['kangaroo', 'plant']
# ['extinct', 'predator', 'kangaroo']
# ['leopard', 'smaller', 'member', 'panthera']
# ['leopard', 'larger', 'lanky', 'cheetah']
# ['large', 'python', 'potential', 'leopard']
# ['leopard', 'mistake']
# ['hybrid', 'animal', 'result', 'union', 'leopard']
# ['leopard', 'often', 'kill']
# ['early', 'naturalist', 'distinguish', 'leopard', 'panther']
# ['leopard', 'know', 'colloquially']
# ['shape', 'leopard', 'black', 'ros08_settes', 'africa']
# ['leopard', 'world', 'mammal']
# ['leopard', 'felidae', 'family']
# ['leopard']
# ['leopard', 'distribute']
# ['leopard']
# ['leopard', 'weigh']
# ['leopard', 'weigh', 'female', 'leopard']
# ['difference', 'leopard', 'cheetah']
# ['distribution', 'leopard', 'compare', 'distribution']
# ['liechtenstein', 'border', 'switzerland']
# ['liechtenstein', 'small', 'german', 'speaking', 'country', 'world']
# ['liechtenstein', 'ancient', 'roman', 'province', 'raetia']
# ['first', 'factory', 'open']
# ['municipality', 'liechtenstein', 'divide']
# ['national', 'currency', 'liechtenstein']
# ['leichtenstein', 'work', 'promote', 'county', 'image', 'prosecute', 'international', 'money', 'laundering']
# ['company', 'administer', 'leichtenstein', 'railway']
# ['percentage', 'liechtenstein', 'population', 'foreign']
# ['airport', 'liechtenstein']
# ['liechtenstein', 'heavily', 'urbanize']
# ['liechtenstein', 'doubly', 'landlocked']
# ['liechtenstein']
# ['liechtenstein', 'current', 'constitution', 'adopt']
# ['official', 'language', 'liechtenstein']
# ['country', 'border', 'liechtenstein']
# ['roman', 'province', 'liechtenstein']
# ['municipality', 'within', 'oberland']
# ['webster', 'write', 'sleep', 'night']
# ['arrival', 'louis', 'kossuth', 'exile', 'leader', 'fail', 'hungarian', 'revolution', 'another', 'issue', 'present', 'fillmore', 'presidency']
# ['11:10', 'march', 'effects', 'stroke']
# ['seward', 'elect', 'senate']
# ['commodore', 'matthew', 'perry', 'japan', 'western', 'trade']
# ['remarkable', 'millard', 'fillmore']
# ['fillmore', 'partnership', 'found', 'private', 'university', 'buffalo']
# ['fillmore', 'president', 'second']
# ['death', 'first', 'fillmore', 'marry', 'caroline', 'mcintosh']
# ['millard', 'fillmore', 'thirteenth', 'president', 'unite', 'state']
# ['millard', 'fillmore', 'january']
# ['millard', 'fillmore', 'march']
# ['millard', 'fillmore']
# ['millard', 'fillmore']
# ['millard', 'fillmore']
# ['taylor', 'fillmore', 'disagree']
# ['fillmore', 'ascend', 'presidency']
# ['supporter', 'henry', 'fillmore']
# ['otter', 'muscular', 'tails']
# ['otter', 'survive', 'water']
# ['giant', 'otter', 'inhabit', 'south', 'africa']
# ['species', 'otter']
# ['river', 'otter']
# ['otter', 'weigh']
# ['otter', 'insulate']
# ['otter', 'nearly', 'extinct']
# ['challenge', 'establish', 'population', 'eurasian', 'otter']
# ['otter', 'mammal']
# ['species', 'genus', 'otter']
# ['otter', 'water']
# ['otter']
# ['otter', 'derive']
# ['otter', 'birth']
# ['drive', 'otter', 'almost', 'extinction']
# ['otter', 'consider', 'totem', 'animal']
# ['otter', 'along', 'pacific', 'coast']
# ['otter', 'totem', 'animal']
# ['otter', 'herbivore']
# ['primary', 'otter']
# ['otter', 'call']
# ['giant', 'otter', 'become', 'increasingly']
# ['otter', 'without', 'blubber']
# ['otter', 'playful', 'animal']
# ['animal', 'relate', 'otter']
# ['penguin', 'krill']
# ['large', 'living', 'species', 'penguin']
# ['penguin', 'almost', 'exclusively', 'southern', 'hemisphere']
# ['tobogganing']
# ['penguin', 'countershaded']
# ['penguin', 'afraid', 'humans']
# ['penguin', 'spend']
# ['species', 'penguin']
# ['isabelline', 'penguin', 'different', 'penguin']
# ['penguin', 'bird']
# ['penguin', 'better', 'average', 'sense', 'hearing', 'bird']
# ['penguin', 'consider', 'higher', 'waterbird']
# ['order', 'penguin', 'belong']
# ['tall', 'prehistoric', 'penguin']
# ['make', 'penguin', 'agile', 'water']
# ['penguin', 'tobaggan']
# []
# ['polar', 'mammal']
# ['polar', 'carnivore']
# ['large', 'polar', 'record']
# ['polar', 'color']
# ['polar', 'guard']
# ['cause', 'polar', 'disease']
# ['polar', 'special', 'species']
# ['fossil', 'evidence']
# ['polar', 'arctic']
# ['polar', 'white', 'color']
# ['polar', 'extinction']
# ['heavy', 'polar']
# ['heavy', 'large', 'polar', 'record']
# ['polar', 'provide']
# ['female', 'polar', 'bear', 'weight']
# ['weight', 'female', 'polar', 'bear', 'pregnancy']
# ['polar', 'bear', 'infrared', 'photography']
# ['qatar', 'eighth', 'rich', 'country', 'world', 'caput']
# ['nearly', 'qatari', 'profess', 'islam']
# ['woman', 'legally', 'drive', 'qatar']
# ['qatar', 'become', 'independent', 'state']
# ['qatar', 'telecommunication', 'system', 'center']
# ['suicide', 'bombing', 'teacher']
# ['native', 'pronunciation', 'qatar', 'sound', 'cutter']
# ['arabic', 'municipality']
# ['university', 'education']
# ['romania', 'border', 'hungary']
# ['romania', 'secular', 'state']
# ['president', 'elect', 'popular']
# ['county', 'romania', 'divide']
# ['high', 'mountain', 'romania']
# ['official', 'language', 'romania']
# ['romanian', 'economy']
# ['romania']
# ['territory', 'join', 'romania']
# ['romania', 'share', 'border', 'ukraine']
# ['romania', 'declare', 'neutrality', 'world']
# ['romania', 'share', 'language', 'moldova']
# ['first', 'gymnast', 'score', 'perfect']
# ['large', 'romania']
# ['large', 'ethnic', 'minority', 'romania']
# ['country', 'europe', 'bigger', 'romania']
# ['romania', 'state', 'religion']
# ['romania', 'neutral', 'world']
# ['singaporean', 'enjoy', 'squid']
# ['singapore', 'standard', 'living', 'decrease', 'since', 'independence']
# ['medium', 'contribute', 'singapore']
# ['people', 'network', 'daily']
# ['orang', 'people']
# []
# ['singapore', 'climate', 'characterize']
# ['increase', 'medium', 'contribution', 'government', 'seeking']
# ['imperial', 'japanese', 'battle', 'singapore']
# ['singapore', 'locate', 'southern', 'korean', 'penisula']
# ['singapore', 'state']
# ['utama', 'visit', 'singapore']
# ['singa']
# ['first', 'record', 's08_settlement', 'singapore']
# ['nation', 'invade', 'singapore', 'world']
# ['churchill', 'call', 'occupation', 'singapor', 'janpan', 'britain', 'greatest', 'defeat']
# ['successful', 'leader', 'singapore']
# ['succeed', 'prime', 'minister']
# ['primary', 'domestic', 'source', 'water', 'supply']
# ['national', 'language', 'singapore']
# ['national', 'orchid', 'garden']
# ['relations', 'malaysia', 'indonesia', 'important']
# ['densely', 'populate', 'independent', 'country', 'world']
# ['thomas', 'stamford', 'raffles']
# ['prime', 'minister', 'singapore']
# ['punishment', 'first', 'degree', 'murder']
# ['thedore', 'roosevelt', 'member', 'republican', 'party']
# ['theodore', 'roosevelt', 'brother']
# ['theodore', 'roosevelt', 'harvard']
# ['theodore', 'roosevelt']
# ['roosevelt', 'improve', 'physical', 'condition']
# ['roosevelt', 'start', 'boxing', 'lesson']
# ['nickname', 'theodore', 'roosevelt', 'sister']
# ['roosevelt', 'justification', 'supporting', 'desegregation', 'school']
# ['newspaper', 'respond', 'roosevelt', 'invite', 'brooker', 'washington', 'dinner', 'white', 'house']
# ['theodore', 'roosevelt', 'study']
# ['roosevelt', 'receive', 'medal', 'honor']
# ['roosevelt', 'study', 'biology']
# ['theodore', 'roosevelt']
# ['roosevelt', 'presidential']
# ['roosevelt']
# ['help', 'roosevelt', 'african', 'safari']
# ['roosevelt', 'support', 'racial', 'integration', 'school']
# ['roosevelt', 'family']
# ['turtle', 'ectothermic']
# ['mother', 'young']
# ['turtle']
# ['shape', 'larest', 'species', 'turtle']
# ['often', 'turtle', 'breed']
# ['turtle', 'tortoise', 'breathe']
# ['turtle', 'reproduce']
# ['discover', 'turtle', 'organs']
# ['suborder', 'turtle', 'draw', 'shell']
# ['turtle', 'sandy', 'beach']
# ['pleurodira', 'know', 'neck', 'turtle']
# ['turtle', 'flying', 'spaghetti', 'monster']
# ['suborder', 'turtle', 'divide']
# ['turtle', 'popularly']
# ['relate', 'article', 'article', 'turtle']
# ['turtle', 'would', 'likely', 'hatch']
# ['turles', 'breathe', 'water']
# ['neck', 'turtle', 'call', 'neck', 'turtle']
# ['turtle', 'underwater']
# ['turtle', 'leathery']
# ['turtle', 'examine', 'longevity', 'gene']
# ['suborder', 'turtle', 'extinct']
# ['turtle', 'preared', 'consist', 'mainly']
# ['turtle']
# ['small', 'suborder', 'turtle']
# ['turtle', 'cover', 'incubate']
# ['creature', 'breathe', 'underwater']
# ['ulysses', 'grant', 'general', 'american', 'civil']
# ['grant', 'father', 'democrat']
# ['ulysses', 'battle', 'champion']
# ['grant', 'brother']
# ['grant']
# ['grant', 'political', 'affiliation']
# ['grant', 'nothing', 'batte']
# ['horace', 'greenley', 'presidential', 'election']
# ['grant', 'think', 'unjust']
# ['uruguay', 'locate', 'northwesten', 'africa']
# ['uruguay', 'capital', 'montevideo']
# ['uruguay', 'summer']
# ['found', 'montevideo']
# ['uruguay', 'old', 'church']
# ['heavily', 'influence', 'architecture', 'culture', 'montevideo']
# ['neighborhood', 'call', 'informally']
# ['uruguay', 'landscape', 'mountainous']
# ['religion', 'uruguayan', 'profess']
# ['uruguay', 'locate', 'south', 'america']
# ['citizen', 'propose', 'change', 'constitution']
# ['uruguay', 'first', 'world']
# ['square', 'kilometre', 'continental', 'uruguay']
# ['population', 'white', 'european', 'descent']
# ['capital', 'uruguay', 'found']
# ['times', 'uruguay', 'world']
# ['average', 'income', 'african', 'woman', 'compare', 'european']
# ['uruguay', 'recognize', 'civil', 'union']
# ['uruguay', 'border', 'french', 'guiana']
# ['uruguay', 'warm', 'month']
# ['citizen', 'propose', 'change', 'constitution']
# ['religion', 'found', 'uruguay']
# ['uruguay', 'competitive', 'agriculture']
# ['names', 'uruguay', 'political', 'party']
# ['uruguay', 'small', 'soverign', 'nation', 'south', 'america']
# ['woodrow', 'wilson', 'thirtieth', 'president', 'unite', 'state']
# ['woodrow', 'wilson', 'create', 'league', 'nation']
# ['league', 'nation']
# ['league', 'nation', 'create']
# ['woodrow', 'wilson']
# ['president', 'wilson', 'finish', 'congressional', 'government']
# ['field', 'woodrow', 'wilson', 'leave', 'practice', 'study']
# ['cause', 'wilson', 'congress', 'declare', 'central', 'power']
# ['damage', 'move', 'student', 'college']
# ['wilson', 'member', 'kappa', 'fraternity']
# ['wilson', 'automobile', 'enthusiast']
# ['wilson', 'father', 'slave']
# ['wilson', 'bury']
# ['wilson', 'attend', 'school']
# ['woodrow', 'wilson']
# ['wilson', 'support', 'desegregation']
# ['wilson', 'support', 'committee', 'system']
# ['wilson', 'sibling']
# ['volta', 'italian', 'physicist']
# ['volta', 'bury', 'pittsburgh']
# ['volta', 'passion', 'study', 'electricity']
# ['battery', 'volta', 'credit']
# ['important', 'electrical', 'name', 'honor', 'volta']
# ['volta', 'enter', 'retirement']
# ['disadvantage', 'something', 'unsafe', 'handle']
# ['lombardy', 'napoleon']
# ['italian', '10.000', 'banknote', 'create']
# ['amedeo', 'avogadro', 'italian']
# ['amedeo', 'avogadro', 'graduate']
# ['avogadro', 'england']
# ['avogadro', 'professor', 'physics']
# ['child', 'avogadro']
# ['avogadro', 'note']
# ['avogadro', 'number']
# ['avogadro', 'teaching', 'turin', 'university']
# ['subject', 'avogadro', 'study', 'first']
# ['anders', 'celcius', 'publish', 'observation', 'aurora', 'borealis']
# ['anders', 'celsius', 'determine', 'boiling', 'water']
# ['temperature', 'scale', 'celsius', 'propose']
# ['boiling', 'point', 'water', 'dependent']
# ['celsius']
# ['celsius', 'report', 'paper', 'observation', 'persistent', 'degree', 'thermometer']
# ['celsius']
# ['temperature', 'would', 'water', 'halfway', 'standard', 'boiling', 'freezing', 'point']
# ['difference', 'celsius', 'original', 'temperature', 'scale', 'today']
# ['insect']
# ['relate']
# ['manage', 'population', 'european', 'honey', 'experience', 'substantial', 'decline']
# []
# ['bumblebee', 'colony', 'reach', 'population']
# ['people', 'commonly', 'cleptoparasitic']
# ['vespoid', 'wasp', 'evolve']
# ['humans']
# ['honey', 'queens', 'continue', 'foraging', 'season']
# ['beijing', 'northern', 'capital']
# ['cave', 'dragon', 'village', 'zhoukoudian', 'fangshan', 'district']
# ['hutongs', 'disappearing']
# ['beijing', 'olympic', 'game']
# ['rebellion', 'launch']
# ['communist', 'force', 'enter', 'without', 'fight']
# ['shikai']
# ['pollution', 'beijing']
# ['august', 'train', 'daily', 'beijing', 'railway', 'station', 'beijing', 'railway', 'station']
# ['blaise', 'pascal', 'mathematician', 'first', 'order']
# ['could', 'blaise', 'pascal', 'without', 'crutch']
# ['pascal', 'given', 'pressure']
# ['pascal', 'suffer', 'throughout']
# ['pascal', 'argue', 'perfect', 'possible']
# ['physician']
# ['eldest', 'sibling']
# ['aside', 'provincial', 'letters', 'religious', 'influence', 'popular', 'literary']
# ['whose', 'continual', 'health', 'cause', 'never', 'precisely', 'determine']
# ['violin', 'cello', 'bow', 'string', 'instrument']
# ['purfling', 'decoration']
# ['hole', 'access', 'point', 'interior', 'cello']
# ['violincello']
# ['material', 'traditionally']
# ['cello']
# ['harmonics', 'produce', 'note', 'middle']
# ['refer', 'cello', 'ï¿½basso', 'viola', 'braccio']
# ['violincello']
# ['cello', 'performance', 'rihanna']
# ['cello', 'construct']
# ['cello', 'string', 'instrument']
# ['cello', 'abbreviation']
# ['position', 'cello']
# ['person', 'play', 'cello', 'call']
# ['purl', 'cello']
# ['first', 'educational', 'works', 'appear', 'cello']
# ['cello', 'manufacturer', 'outside']
# ['charles', 'augustin', 'coulomb', 'member', 'national', 'institute']
# ['charles', 'augustin', 'coulomb', 'relationship', 'electric', 'charge', 'magnetic', 'pole']
# ['charles', 'augustin', 'coulomb', 'father', 'family', 'montpellier']
# ['charles', 'augustin', 'coulomb']
# ['charles', 'augustin', 'coulomb', 'permanently', 'station', 'paris']
# ['contribution', 'charles', 'augustin', 'coulomb', 'field', 'geotechnical', 'engineering']
# ['construction', 'bourbon', 'place']
# ['definition', 'electrostatic', 'force', 'attraction', 'repulsion']
# ['charles', 'augustin', 'coulomb', 'retire', 'small', 'estate', 'possess', 'blois']
# ['copenhagen', 'capital', 'country']
# ['population', 'copenhagen']
# ['transnational', 'bridge', 'complete']
# ['copenhagen', 'regional']
# ['happen', 'copenhagen']
# ['copenhagen', 'completely', 'surround', 'water']
# ['copenhagen', 'rank', 'number', 'worldwide', 'things']
# ['german', 'troops', 'occupy', 'copenhagen']
# ['cymbal', 'historically', 'suggest', 'bacchanal']
# ['origin', 'cymbal', 'trace', 'prehistoric', 'times']
# ['cymbal', 'moden', 'orchestra']
# ['common', 'cymbal']
# ['second', 'orchestral', 'cymbal']
# ['clash', 'cymbal', 'traditionally', 'accompany']
# ['happen', 'center', 'cymbal']
# ['effective', 'accentuate']
# ['cymbal', 'expert', 'player', 'obtain', 'enormous', 'dynamic', 'range']
# ['origin', 'cymbal', 'trace', 'prehistoric', 'times']
# ['modern', 'evolve', 'clash', 'cymbal']
# ['cymbal', 'derive', 'germanic']
# ['center', 'cymbal', 'call']
# ['cymbal', 'crash']
# ['instrument', 'modern']
# ['greek', 'mythical', 'creature', 'depict', 'holding', 'cymbal']
# ['orchestral', 'crash', 'cymbal', 'technically', 'call']
# ['dhaka', 'capital', 'bangladesh']
# ['dhaka', 'locate', 'eastern', 'banks', 'buriganga', 'river']
# ['university', 'dhaka', 'large', 'public', 'university', 'dhaka']
# ['dhaka', 'cover']
# ['people', 'bhola', 'cyclone']
# ['independence', 'bangladesh']
# ['mughals', 'arrive', 'dhaka']
# ['university', 'dhaka', 'older', 'dhaka', 'college']
# ['flute', 'musical', 'instrument']
# ['possible', 'flute']
# ['indian', 'concert', 'flute', 'available', 'standard', 'pitch']
# ['refer', 'musician', 'flute']
# ['three', 'hole', 'flute', 'mammoth', 'discover']
# ['whistle', 'first', 'appear']
# ['old', 'know', 'musical', 'instrument']
# ['flute', 'spread', 'parts', 'europe']
# ['stream', 'across', 'create']
# ['fox', 'humans']
# ['fennec', 'fox', 'endanger']
# ['fox', 'include', 'reptile']
# ['fox']
# ['country', 'hunting', 'originate']
# ['small', 'species']
# ['female', 'fox', 'call']
# ['cache']
# ['fox', 'damage', 'fruit', 'farm']
# ['sex', 'giraffe', 'horn']
# ['giraffe', 'birth', 'standing']
# ['giraffe', 'hunt', 'hide']
# ['area', 'giraffe', 'inhabit']
# ['giraffe', 'clean', 'appear']
# ['giraffe', 'defend']
# ['giraffe', 'weigh', 'female', 'giraffe']
# ['giraffe', 'larger', 'horn', 'female', 'giraffe']
# ['female', 'generally', 'tall', 'female', 'giraffe']
# ['henri', 'becquerel', 'discoverer', 'radioactivity']
# ['radioactivity', 'name']
# ['henri', 'becquerel', 'french', 'physicist']
# ['henri', 'becquerel']
# ['henri', 'becquerel']
# ['henri', 'becquerel', 'nobel', 'prize', 'physics']
# ['henri', 'becquerel', 'first', 'family', 'occupy', 'physics', 'chair', 'museum', 'national', "d'histoire", 'naturelle']
# ['henri', 'becquerel', 'winner', 'nobel', 'prize', 'physics']
# ['henri', 'becquerel', 'intentionally', 'discover', 'radioactivity']
# ['newton', 'english', 'physicist']
# ['newton', 'reject', 'church', 'doctrine', 'trinity']
# ['newton', 'admit', 'havard', 'college']
# ['newton', 'birth', 'record']
# ['motion', 'netwon']
# ['newton', 'master', 'creator']
# ['netwon', 'investigate', 'refraction', 'light']
# ['principle', 'newton', 'explain', 'mechanics']
# ['interaction', 'stir', 'newton', 'interest', 'alchemy']
# ['james', 'improvement', 'fundamental', 'change', 'work', 'industrial', 'revolution']
# ['james']
# ['james', 'mother']
# ['james', 'child', 'adulthood']
# ['james', 'rank', 'first', 'among', 'people', 'charles', 'murray', 'survey', 'historiometry']
# ['james', 'travel', 'lodon', 'study', 'instrument', 'making']
# ['years', 'james', 'mother', 'alive']
# ['james', 'famous']
# ['capital']
# ['museum']
# ['volleyball', 'venue']
# ['found']
# ['reserve', 'locate']
# ['colectivo']
# ['national', 'university', 'marcos']
# ['lorenzo', 'megaport', 'project', 'complete']
# ['london', 'capital', 'unite', 'kingdom']
# ['london', 'population', 'range', 'religion']
# ['caunte', 'control', 'english', 'throne']
# ['language', 'speak', 'london']
# ['anglo', 'saxon', 'create']
# ['subject', 'bout', 'terrorism']
# ['country', 'james', 'scotland', 'unite']
# ['civil', 'affect', 'england', 'middle']
# ['strings', 'classical']
# ['classical', 'sound', 'chest']
# ['play', 'mordern', 'greece']
# ['strings', 'touch']
# ['place', 'still', 'play']
# ['classical', 'fingerboard']
# ['guitar', 'play', 'plectrum']
# ['michael', 'faraday', 'english', 'chemist']
# ['faraday', 'devout', 'christian']
# ['faraday', 'consider', 'gentleman']
# ['member', 'sandemanian', 'christianity']
# ['joseph', 'henry', 'likely', 'discover']
# ['university', 'oxford', 'grant', 'faraday']
# ['travel', 'outside', 'coach']
# ['faraday', 'construct', 'ancestor', 'modern', 'power', 'generator']
# ['faraday', 'lecture', 'education']
# ['faraday', 'receive', 'extensive', 'formal', 'education']
# ['faraday', 'discover', 'chemical', 'substance', 'benzene']
# ['faraday', 'england']
# ['historian', 'science', 'refer', 'faraday']
# ['sponsor', 'mentor', 'faraday']
# ['faraday', 'invent', 'almost', 'universally', 'science', 'laboratory']
# ['production', 'chemical', 'weapon', 'raise', 'ethical', 'issue']
# ['faraday', 'effect', 'first', 'call']
# ['someone', 'attending', 'church']
# ['nassau', 'sound', 'water', 'maine']
# ['nassau', 'place', 'operation', 'robert', 'fulton']
# ['nassau', 'build']
# ['nassau', 'coliseum']
# ['alive', 'fighting', 'arena', 'model']
# ['nassau', 'range', 'high', 'mountain', 'range', 'world']
# ['nassau', 'county', 'name', 'german']
# ['unite', 'state', 'glasgow']
# ['tesla', 'study', 'electrical', 'engineering']
# ['tesla', 'unite', 'state']
# ['tesla', 'hire', 'edison']
# ['tesla', 'demonstrate', 'wireless', 'communication', 'radio']
# ['measuring', 'magnetic', 'density', 'magnetic', 'induction']
# ['tesla', 'regard', 'scientist']
# ['current', 'tesla', 'invent']
# ['victor', 'current']
# ['tesla', 'study', 'electrical', 'engineering']
# ['ottawa', 'capital', 'canada']
# ['ottawa', 'ottowa', 'river']
# ['small', 'tremor', 'occur', 'ottawa']
# ['ottawa', 'population']
# ['ottawa', 'primary', 'industry']
# ['ottawa', 'junior', 'hockey']
# ['ottawa', 'major', 'league', 'hockey']
# ['carleton', 'university', 'athletic', 'team', 'call']
# ['ottawa', 'cold', 'moscow', 'january']
# ['ottawa', 'river']
# ['ottawa']
# ['cholera', 'outbreak']
# ['mayor', 'ottawa']
# ['township', 'ottawa']
# ['highway', 'ottawa']
# ['ottawa']
# ['base', 'average', 'small', 'tremor', 'occur', 'ottawa']
# ['immigrant', '1800s']
# ['giant', 'otter', 'south', 'america']
# ['otter', 'claw']
# ['otter']
# ['otter', 'vulnerable', 'depletion']
# ['otter', 'enjoy', 'playing']
# ['otter', 'layer', 'whale']
# ['otter', 'family', 'badger']
# ['city', 'name', 'santiago', 'unite', 'state']
# ['santiago', 'indie']
# ['santiago', 'spanish']
# ['origin', 'santiago']
# ['release', 'album', 'name', 'santiago']
# ['order', 'santiago']
# ['notable', 'people', 'name', 'santiago']
# ['fictional', 'story', 'include', 'character', 'name', 'santiago']
# ['australian', 'black', 'white', 'feather', 'wings']
# ['swan', 'belong', 'family', 'anatidae']
# ['black', 'swan']
# ['young', 'swan', 'know']
# ['irish', 'legend', 'child']
# ['sanskrit']
# ['album', 'bonny', 'swan']
# ['polish']
# ['ballet', 'pyotr', 'tchaikovsky', 'partially', 'base', 'ancient', 'german', 'legend', 'princess', 'turn']
# ['bird', 'family', 'anatidae']
# ['swan', 'feature', 'strongly', 'mythology']
# ['trumpeter', 'large']
# ['young', 'swan']
# ['derive']
# ['know', 'story']
# ['swan', 'duck', 'bird', 'family']
# ['adult', 'female']
# ['color', 'australian', 'black']
# ['tiger', 'member', 'felidar', 'family']
# ['tigers', 'solitary', 'animal']
# ['panther', 'tiger']
# ['tigers', 'powerfully', 'build', 'shoulder', 'allow', 'tigers']
# ['would', 'tiger', 'seize', 'crocodile']
# ['typical', 'feature', 'tiger', 'country']
# ['would', 'common', 'tigers', 'january']
# ['square', 'kilometer', 'would', 'need', 'house', 'female', 'tigers']
# ['would', 'tiger', 'likely', 'feedon', 'smaller', 'animal']
# ['predecessor', 'trumpets', 'valve']
# ['trumpets', 'construct', 'brass']
# ['trumpet', 'small', 'trumpet']
# ['musical', 'style', 'trumpet']
# ['common', 'trumpet']
# ['trumpet', 'produce', 'sound']
# ['trumpets', 'compensate', 'tone']
# ['mile', 'davis', 'trumpet']
# ['trumpet', 'mellow', 'cornet']
# ['upper', 'shell', 'turtle', 'call', 'plastron']
# ['scute', 'turtle', 'shell']
# ['terrestrial', 'tortoise', 'short']
# ['group', 'turtle', 'break']
# ['survive', 'giant', 'tortoise']
# ['turtle']
# ['tortoise', 'base']
# ['turtle', 'lay']
# ['turtle', 'consider', 'delicacy']
# ['testudines', 'crown', 'group', 'superorder', 'chelonia']
# ['turtle', 'breathe']
# ['harvesting', 'turtle', 'legal', 'anywhere']
# ['approximately', 'species', 'testudines', 'alive', 'today']
# ['harvesting', 'turtle', 'legal']
# ['large', 'chelonian']
# ['approximate', 'turtle']
# ['turtle', 'spend', 'underwater']
# ['violinist', 'fiddler', 'thing']
# ['violin', 'single']
# ['viola', 'cello', 'family', 'instrument', 'violin']
# ['violin']
# ['someone', 'make', 'violin', 'call']
# ['strings', 'violin', 'usually']
# ['violin']
# ['people', 'making', 'instrument', 'violin']
# ['whate', 'usual', 'pitch', 'range', 'violin']
# ['xylophone', 'rosewood']
# ['xylophone', 'precursor', 'vibraphone']
# ['ancient', 'mallet', 'copper']
# ['xylophone', 'originate']
# ['earliest', 'historical', 'reference', 'europe']
# ['western', 'style', 'xylophone', 'characterise']
# ['xylophone', 'octave']
# ['short', 'follow']
# ['vibraphone', 'exist']
# ['alessandro', 'volta', 'professor', 'chemistry']
# ['alessandro', 'volta', 'invent', 'remotely', 'operate', 'pistol']
# ['alessandro', 'volta', 'teach', 'public', 'school']
# ['alessandro', 'volta', 'marry']
# ['alessandro', 'volta', 'invent']
# ['battery', 'alessandro', 'volta', 'credit']
# ['alessandro', 'volta', 'retire', 'place']
# ['alessandro', 'volta', 'improve', 'popularize', 'electrophorus']
# ['alessandro', 'volta', 'professor', 'university', 'pavia']
# ['alessandro', 'volta', 'egyptian']
# ['volta', 'teach', 'public', 'school']
# ['volta', 'count']
# ['volta', 'count']
# ['volta']
# ['volta', 'retire']
# ['improve', 'popularize', 'electrophorus', 'volta', 'become']
# ['volta', 'bury', 'bury', 'someplace']
# ['volta', 'marry', 'become', 'professor', 'experimental', 'physics', 'university', 'pavia']
# ['avogadro', 'professor', 'university', 'turin']
# ['member', 'royal', 'superior', 'council', 'public', 'instruction']
# ['avogadro', 'number', 'compute', 'result', 'chemical', 'reaction']
# ['first', 'calculate', 'value', 'avogadro', 'number']
# ['avogadro', 'state']
# ['show', 'avogadro', 'theory', 'dilute', 'solution']
# ['language', 'paper', 'publish']
# ['avogadro']
# ['avogadro', 'chair', 'university', 'turin']
# ['amedeo', 'avogadro', 'turin']
# ['avogadro', 'hail', 'founder', 'atomic', 'molecular', 'theory']
# ['johann', 'josef', 'loschmidt', 'first', 'calculate', 'value', 'avogadro', 'number']
# ['avogadro', 'become', 'professor', 'physics']
# ['avogadro', 'actually']
# ['number', 'elementary', 'entity', 'substance', 'know']
# ['would', 'german', 'avogadro', 'number']
# ['amedeo', 'avogadro', 'italian']
# ['become', 'professor', 'revolutionary', 'movement', 'sardinia']
# ['belong', 'hymenoptera', 'order']
# ['cuisine']
# ['contain', 'sensory', 'organs']
# ['travel']
# ['colony', 'fertile', 'female', 'call']
# ['write', 'tramp', 'abroad']
# ['plant', 'meat']
# ['organs', 'give', 'sight']
# ['happen', 'boiling', 'water', 'queen']
# ['found', 'antartica']
# ['flight', 'female']
# ['worker', 'wings']
# ['three', 'segment']
# ['colony', 'queens', 'call']
# ['bullet', 'locate']
# ['belong', 'order']
# ['common', 'color']
# ['build', 'nest']
# ['antwerp']
# ['antwerp', 'municipality']
# ['antwerp', 'belgium']
# ['antwerp']
# ['population', 'antwerp']
# ['antwerp']
# ['antwerp', 'important', 'fashion']
# ['antwerp', 'river']
# ['municipality', 'antwerp']
# ['arabic', 'central', 'semitic', 'language']
# ['arabic', 'major', 'vehicle', 'culture', 'europe']
# ['arabic', 'classified', 'alongside', 'semitic', 'language']
# ['people', 'speak', 'arabic', 'language']
# ['arabic', 'calligraphy', 'invent']
# ['arabic', 'speak']
# ['arabic', 'relate', 'islam']
# ['arabic', 'heavily', 'influence', 'european', 'language']
# ['arabic', 'large', 'member', 'semitic', 'language', 'family']
# ['modern', 'standard', 'arabic', 'continue', 'evolve', 'language']
# ['hassaniya', 'arabic', 'speak', 'mauritania']
# ['variety', 'modern', 'arabic', 'acquire', 'official', 'language', 'status']
# ['egyptian', 'arabic', 'speak', 'egypt']
# ['western', 'arabic', 'numeral']
# ['active', 'academy', 'arabic', 'language', 'found']
# ['hassan', 'massoudy', 'master', 'genre']
# ['berlin', 'capital', 'germany']
# ['berlin', 'large', 'germany']
# ['schloss', 'charlottenburg', 'large', 'exist', 'palace', 'berlin']
# ['building', 'german', 'parliament']
# ['sport', 'event', 'olympiastadion']
# ['berliner', 'locate']
# ['berlin', 'building', 'architect', 'norman', 'foster', 'remodel', '1990s']
# ['vattenfall', 'shifting', 'towards', 'reliance', 'cleaner', 'renewable', 'energy', 'source']
# ['names', 'berlin']
# ['berlin', 'headquarters', 'springer']
# ['gendarmenmarkt', 'border', 'french', 'cathedral']
# ['nauen', 'plain', 'north', 'berlin']
# ['queen', 'nefertiti']
# ['german', 'president']
# ['berlin', 'status', 'hanseatic']
# ['busy', 'airport', 'berlin']
# ['occupation', 'zone', 'germany', 'divide']
# ['popkomm', 'move', 'berlin']
# ['blaise', 'pascal', 'father']
# ['pascal', 'french', 'mathematician']
# ['pascal', 'health', 'throughout']
# ['pascal', 'mother']
# ['pascal', 'younger', 'sister']
# ['pascal', 'religious', 'conversion']
# ['pascal']
# ['pascal', 'write', 'cycloid']
# ['programming', 'language', 'call', 'pascal']
# ['butterfly', 'sound']
# ['butterfly']
# ['black', 'someone']
# ['outer', 'layer', 'cuticle']
# ['swarm', 'butterfly']
# ['butterfly', 'migratory']
# ['butterfly', 'carry', 'pollen', 'hymenoptera']
# ['allow', 'butterfly', 'evade', 'predator']
# ['happen', 'remove']
# ['charles', 'augustin', 'coulomb', 'spanish', 'biologist']
# ['charge', 'name', 'charles', 'augustin', 'coulomb']
# ['charles', 'augustin', 'coulomb', 'employ', 'rochelle']
# ['charles', 'augustin', 'coulomb', 'know']
# ['whose', 'idea', 'inspire', 'charles', 'augustin', 'coulomb', 'experiment', 'resistance', 'masonry']
# ['charles', 'augustin', 'coulomb', 'father', 'family', 'montpeillier']
# ['charles', 'augustin', 'coulomb', 'family']
# ['coulomb']
# ['collège', 'quatre', 'nation', 'locate']
# ['speak', 'variety', 'chinese', 'tonal', 'analytical']
# ['fifty', 'percent', 'korean', 'vocabulary', 'chinese', 'origin']
# ['ketchup', 'minnan', 'pronunciation', '39853;&#27713', 'tsiap']
# ['common', 'romanization', 'standard', 'standard', 'mandarin', 'today']
# ['official', 'standard', 'language', 'people', 'republic', 'china', 'republic', 'china', 'singapore', 'call', 'huayu']
# ['entry', 'character', 'definition', 'zhonghua', 'zihai', '20013;&#21326;&#23383;&#28023', 'contain']
# ['government', 'classify', 'literacy', 'amongst', 'worker']
# ['south', 'china', 'linguistically', 'different', 'north', 'china']
# ['20415;&#24403;/&#20415;&#30070', '\x93lunchbox', 'box', 'lunch\x94', 'bento', '26009;&#29702', '\x93prepared', 'cuisine\x94', 'words', 'language']
# ['standardize', 'speak', 'chinese']
# ['diglossia', 'common', 'feature', 'mainland', 'china', 'taiwan']
# ['linguist', 'often', 'chinese', 'language', 'family']
# ['classical', 'chinese', 'literature', 'begin']
# ['government', 'people', 'republic', 'china', 'often', 'refer', 'division', 'sinitic', 'language(s', 'besides', 'standard', 'mandarin']
# ['middle', 'chinese']
# ['pronunciation', 'foreign', 'words', 'determine']
# ['total', 'number', 'chinese', 'words']
# ['language', 'southern', 'dynasty']
# ['cougar', 'know', 'mountain']
# ['cougar', 'larger', 'jaguar']
# ['world', 'conservation', 'union', 'consider', 'cougar', 'least', 'concern', 'species']
# ['cougar', 'primary', 'source']
# ['cougar', 'adult', 'male']
# ['adult', 'cougar', 'print']
# ['three', 'heavy', 'world']
# ['average', 'cougar', 'male', 'heavy', 'female']
# ['three', 'species', 'native', 'canada']
# ['parts', 'cymbal', 'call']
# ['cymbal', 'common']
# ['fender', 'cymbal']
# ['cymbal']
# ['timber', 'ancient', 'cimbals', 'disfluent']
# ['sound', 'cymbal', 'cello']
# ['cymbal']
# ['cymbal', 'typically']
# ['kind', 'musical', 'group', 'cymbal']
# ['member', 'percussion', 'group']
# ['serve', 'musical', 'purpose']
# ['aburukuwa']
# ['basic', 'design', 'remain', 'unchanged']
# ['second', 'big', 'factor', 'affect', 'sound', 'produce']
# ['drum', 'classified', 'percussion', 'group']
# ['drummer', 'drumhead']
# ['whare', 'drum', 's10_set', 'wire', 'across', 'head']
# ['drum', 'lanka', 'since', 'christ']
# ['drum', 'often', 'music', 'therapy']
# ['drum', 'consist', 'least', 'eight', 'membrane']
# ['effect', 'sound']
# ['construct', 'using', 'diatonic', 'chromatically', 'tune', 'drum']
# ['drum', 'usually', 'play']
# ['design', 'drum', 'change', 'recently']
# ['cylindrical', 'shell', 'drum', 'head']
# ['every', 'drumhead', 'sound']
# ['electric']
# ['predator']
# ['blood', 'toxic', 'humans']
# ['species']
# ['smoke', 'consider', 'delicacy']
# ['begin']
# ['type']
# ['leptocephalus']
# ['fresh', 'water']
# ['finnish', 'official', 'language', 'european', 'union']
# ['dialect', 'finnish', 'divide', 'group']
# ['finnish', 'threaten', 'english']
# ['proto', 'uralic', 'language', 'arrive', 'finland']
# ['characteristic', 'feature', 'finnish']
# ['language', 'speak']
# ['classification', 'dialect', 'speak', 'outside', 'finland', 'controversial', 'issue']
# ['write', 'first', 'novel', 'finnish']
# ['define', 'official', 'finnish', 'language']
# ['earliest', 'extant', 'transverse', 'flute']
# ['flute', 'produce', 'sound']
# ['flute', 'volume', 'increase']
# ['end', 'flute', 'bright', 'timbre']
# ['old', 'flute', 'discover', 'found']
# ['western', 'flute', 'simple', 'indian', 'flute']
# ['police', 'whistle', 'pitch']
# ['variety', 'indian', 'flute']
# ['flute', 'date', 'prehistoric', 'times']
# ['flute', 'greece']
# ['flute', 'play', 'several', 'different', 'source']
# ['flute', 'greece']
# ['concert', 'flute', 'begin', 'appearing', 'concert', 'ensemble']
# ['variety', 'indian', 'flute', 'currently']
# ['material', 'flute', 'fashion']
# ['flute', 'player', 'change', 'pitch', 'sound']
# ['basic', 'flute']
# ['dragon', 'historically', 'serve', 'china', 'national', 'emblem']
# ['panda', 'hibernate']
# ['giant', 'panda', 'attack', 'humans']
# ['family', 'panda']
# ['panda']
# ['different', 'names', 'chinese', 'writings', 'panda']
# ['food', 'panda']
# ['subspecies', 'giant', 'panda']
# ['panda', 'diplomacy']
# ['giant', 'panda', 'mammal']
# ['giant', 'panda', 'terrestrial', 'animal']
# ['giant', 'panda', 'endanger', 'species']
# ['giant', 'panda']
# ['giant', 'panda', 'genome', 'sequence']
# ['subspecies', 'giant', 'panda']
# ['giant', 'panda', 'carnivore']
# ['giant', 'panda', 'endanger', 'species']
# ['population', 'giant', 'panda', 'growing']
# ['acoustic', 'guitar', 'dependent', 'external', 'device']
# ['battente', 'smaller', 'classical', 'guitar']
# ['flamenco', 'guitar', 'similar', 'classical', 'guitar']
# ['headstock', 'locate']
# ['guitar', 'repair']
# ['modern', 'guitar', 'strings', 'construct']
# ['guitar', 'difficult', 'classify']
# ['bridge']
# ['guitar', 'three', 'single', 'pickup']
# ['guitar', 'instrument']
# ['guitar', 'divide', 'broad', 'category']
# ['pick', 'shape', 'size']
# ['strings', 'guitar', 'typically']
# ['locate', 'guitar', 'furthest']
# ['electric', 'guitar', 'body']
# ['people', 'believe', 'hand', 'people', 'learn', 'guitar', 'right', 'hand', 'people']
# ['old', 'know', 'representation', 'guitar', 'intrument', 'play']
# ['point', 'call', 'bolt', 'glue', 'guitar']
# ['becquerel', 'study', 'science', 'école', 'ponts', 'chaussées']
# ['become', 'chief', 'engineer', 'department', 'bridges', 'highway']
# ['becquerel', 'french', 'physicist']
# ['share', 'nobel', 'prize']
# ['radioactivity', 'call']
# ['becquerel', 'discover', 'radioactivity', 'whose', 'investigate']
# ['crater', 'name', 'becquerel']
# ['bequerel', 'nobel', 'prize', 'physics']
# ['isaac', 'newton', 'british']
# ['isaac', 'newton', 'religious']
# ['isaac', 'newton']
# ['isaac', 'newton']
# ['share', 'credit', 'isaac', 'newton', 'developing', 'calculus']
# ['isaac', 'newton', 'discover', 'generalize', 'binomial', 'theorem']
# ['occult', 'influence', 'newton', 'theory', 'gravitation']
# ['newton', 'religious', 'view', 'consistent', 'anglicanism']
# ['fruit', 'inspire', 'isaac', 'newton', 'theory', 'gravitation']
# ['isaac', 'newton', 'english', 'physicist', 'mathematician']
# ['build', 'first', 'practical', 'reflect', 'telescope']
# ['isaac', 'newton', 'educate', 'schol', 'grantham']
# ['principia', 'publish']
# ['newton', 'statue', 'display']
# ['isaac', 'newton', 'bury']
# ['religion', 'isaac', 'newton', 'follow']
# ['isaac', 'newton', 'clue', 'theory', 'gravity']
# ['wisma', 'building', 'tall', 'building', 'indonesia']
# ['chinese', 'community', 'jakarta']
# ['jakarta', 'large', 'world']
# ['capital', 'indonesia']
# ['official', 'jakarta']
# ['climate']
# ['jakarta']
# ['governor', 'chosen']
# ['jakarta', 'suffer', 'frequent', 'flooding']
# ['big', 'university', 'jakarta', 'university', 'indonesia']
# ['jakarta']
# ['important', 'river', 'ciliwung', 'river']
# ['jakarta', 'locate']
# ['create', 'monas']
# ['mikrolets', 'travel', 'roads']
# ['contribute', 'frequent', 'flooding', 'jakarta']
# ['economy', 'improve', 'jakarta']
# ['james', 'french']
# ['james', 'improve', 'engine']
# ['statue', 'white', 'house']
# ['james', 'father']
# ['retire']
# ['james', 'memorial', 'college']
# ['name']
# ['attend', 'university']
# ['invent']
# ['korean', 'official', 'language', 'korea']
# ['korean', 'derive', 'goryeo']
# ['dialect', 'korean', 'similar']
# ['korean', 'speaker']
# ['older', 'english', 'source', 'korean', 'refer']
# ['official', 'language', 'north', 'korea']
# ['english', 'translation', 'korean', 'adjective', 'misleadingly', 'suggest', 'verb']
# ['majority', 'loanword', 'korean']
# ['korean', 'speaker']
# ['parts', 'speech', 'korean', 'language', 'contain']
# ['paradigm', 'korean']
# ['korean', 'system', 'numbers', 'base']
# ['another', 'korean', 'adjective']
# ['modern', 'korean', 'write', 'column']
# ['percentage', 'korean', 'language', 'jeong', 'estimate', 'korean']
# ['chinese', 'japanese', 'space', 'words']
# ['language', 'korean', 'descend']
# ['kuala', 'lumpur', 'capitol', 'malaysia', 'disfluent']
# ['kuala', 'lumpur', 'selangor', 'state']
# ['population', 'kuala', 'lumpur']
# ['language', 'speak', 'kuala', 'lumpur']
# ['kuala', 'lumpur']
# ['airport', 'kuala', 'lumpur']
# ['kuala', 'lumpur', 'occupy', 'japanese']
# ['season', 'kuala', 'lumpur', 'experience']
# ['colonial', 'building', 'kuala', 'lumpur', 'construct']
# ['formula', 'world', 'championship']
# ['central', 'market', 'locate', 'proximity', 'pertama', 'complex']
# ['parliament', 'malaysia']
# ['kuala', 'lumpur', 'become', 'federal', 'territory', 'malaysia']
# ['population']
# ['official', 'religion', 'country']
# ['industrialize', 'region', 'malaysia']
# ['election', 'party', 'parliament', 'seats']
# ['event', 'draw', 'world', 'rider', 'malaysia']
# ['lobster', 'invertebrate']
# ['lobster', 'kosher']
# ['lobster', 'blood']
# ['lobster']
# ['lobster', 'found']
# ['level', 'mercury', 'american', 'lobster']
# ['lobster']
# ['moche', 'people', 'worship', 'lobster']
# ['caridoid', 'escape', 'reaction']
# ['recitation', 'ancient', 'greek', 'accompany', 'playing']
# ['classical', 'hollow']
# ['string', 'musical', 'instrument']
# ['constellation', 'resemble', 'shape']
# ['raise', 'extend', 'sound', 'chest', 'classical']
# ['strings', 'classical']
# ['pedal', 'framework', 'piano', 'call']
# ['deep', 'classical', 'relation', 'player']
# ['standard', 'piano', 'fewer', 'strings']
# ['malay', 'official', 'language']
# ['could', 'malay', 'originate', 'sumatra', 'island']
# ['malay', 'agglutinative', 'language']
# ['family', 'malay', 'member']
# ['basic', 'order', 'malay']
# ['language', 'malay', 'borrow', 'words']
# ['words', 'malay', 'natural', 'gender']
# ['words', 'form', 'malay']
# ['malay', 'austronesian', 'family', 'language']
# ['negation', 'malay']
# ['parts', 'speech', 'malay']
# ['national', 'language', 'malaysia']
# ['linguist', 'consider', 'malay', 'single', 'language']
# ['speaker', 'modern', 'malay', 'understand', 'malay']
# ['language', 'besides', 'malay', 'austronesia', 'language', 'family']
# ['melbourne', 'capital', 'populous', 'state', 'victoria']
# ['melbourne', 'australia', 'busy', 'seaport']
# ['melbourne', 'large', 'international', 'student', 'community']
# ['resident', 'melbourne', 'know']
# ['melbourne', 'officially', 'declare']
# ['sister', 'city', 'melbourne']
# ['melbourne', 'situate']
# ['domestic', 'tourist', 'visit', 'melbourne']
# ['religion', 'hold', 'majority', 'melbourne']
# ['albert', 'einstein', 'photograph', 'faraday', 'study']
# ['faraday', 'marry', 'sarah', 'barnard']
# ['faraday', 'discover', 'electrolysis']
# ['discover', 'benzene']
# ['michael', 'faraday']
# ['faraday', 'effect']
# ['faraday', 'discover', 'diamagnetism']
# ['sibling', 'faraday']
# ['michael', 'faraday', 'bury']
# ['faraday', 'know', 'kinematics']
# ['active', 'call', 'environmental', 'science']
# ['discover', 'benzene']
# ['mentor']
# ['faraday']
# ['advise', 'british', 'government', 'production', 'chemical', 'weapon', 'crimean']
# ['faraday', 'strong', 'maritime', 'interest']
# ['charge', 'reside', 'interior', 'charge', 'conductor']
# ['english', 'language', 'often', 'speak', 'montreal']
# ['montreal', 'economy', 'third', 'large', 'city', 'canada']
# ['popular', 'sport', 'montreal', 'hockey']
# ['international', 'airport', 'montreal']
# ['mayor', 'montreal']
# ['large', 'church', 'montreal']
# ['montreal', 'industry', 'early', 'century']
# ['montreal', 'contain', 'large', 'church', 'canada']
# ['large', 'primarily', 'french', 'speaking', 'western', 'world']
# ['nairobi', 'capital', 'kenya']
# ['nairobi', 'found']
# ['current', 'estimate', 'population', 'nairobi', 'milion']
# ['current', 'estimate', 'population', 'nairobi']
# ['nairobi', 'found']
# ['embassy', 'nairobi', 'bomb', 'august']
# ['civilian', 'embassy', 'bombing']
# ['trade']
# ['people', 'estimate', 'nairobi']
# ['nikola', 'tesla', 'alone']
# ['nikola', 'tesla', 'close', 'friend', 'twain']
# ['nikola', 'tesla', 'technique', 'call', 'picture', 'thinking']
# ['nikola', 'tesla', 'appear', 'cover', 'magazine']
# ['become', 'adversary', 'nikola', 'tesla']
# ['nikola', 'tesla']
# ['nikola', 'tesla', 'mother', 'illiterate']
# ['sibling', 'nikola', 'tesla']
# ['nikola', 'tesla', 'vegetarian']
# ['monument', 'tesla', 'niagara', 'falls']
# ['tesla', 'american', 'citizen']
# ['tesla', 'cover', 'magazine']
# ['tesla', 'receive', 'patent']
# ['language', 'tesla', 'speak']
# ['tesla', 'nobel', 'prize']
# ['tesla', 'death']
# ['music', 'group', 'name', 'tesla']
# ['octopus', 'cephalopod']
# ['octopus']
# ['octopus']
# ['mouth', 'octopus']
# ['around', 'recognize', 'octopus', 'species']
# ['octopus']
# ['range', 'lifespan', 'octopus']
# ['example', 'something', 'octopus', 'learn', 'research', 'experiment']
# ['octopus', 'defend', 'predator']
# ['piano', 'western', 'music']
# ['upright', 'piano', 'call', 'vertical', 'piano']
# ['bartolomeo', 'cristofori', 'invent', 'modern', 'piano']
# ['middle', 'pedal', 'call', 'grand', 'piano']
# ['black', 'modern', 'piano']
# ['sustain', 'pedal', 'call']
# ['irving', 'berlin', 'piano', 'locate']
# ['piano', 'irving', 'berlin']
# ['pedal', 'grand', 'piano', 'call', 'corda']
# ['advantageous', 'grand', 'piano', 'metal', 'plate', 'quite', 'massive']
# ['mechanism', 'upright', 'piano', 'perpendicular']
# ['typical', 'studio', 'piano']
# ['piano', 'generally']
# ['total', 'typical', 'modern', 'piano']
# ['upright', 'piano', 'compact']
# ['older', 'piano', 'modern', 'piano']
# ['names', 'piano', 'pedal']
# ['portuguese', 'official', 'language', 'andorra']
# ['portuguese', 'language', 'roots', 'latin', 'language']
# ['portuguese', 'contain', 'words', 'arabic', 'language']
# ['small', 'portuguese', 'speaking', 'community']
# ['group', 'portuguese', 'dialect']
# ['event', 'mark', 'portuguese', 'period']
# ['government', 'establish', 'portuguese', 'third', 'official', 'language', 'order', 'requirement', 'apply', 'membership']
# ['total', 'population', 'portuguese', 'speaker', 'world']
# ['country', 'portuguese', 'official', 'language', 'cantonese', 'chinese']
# ['name', 'apostle', 'saint', 'peter']
# ['terrain', 'artificially', 'raise']
# ['names']
# ['festival', 'feature', 'firework', 'celebrate', 'school']
# ['people', 'urban', 'saint', 'petersburg']
# ['russia', 'large', 'foundry']
# ['crime', 'level', 'become', 'higher']
# ['travel', 'moscow']
# ['standard', 'living', 'franciscio']
# ['francisco', 'percentage', 'lesbian', 'individual']
# ['franscico', 'popular', 'tourist', 'destination']
# ['large', 'population', 'francisco']
# ['state', 'parks', 'francisco']
# ['francisco']
# ['cause', 'local', 'earthquake']
# ['resident', 'employ', 'small', 'business']
# ['poverty', 'francisco', 'compare', 'nation', 'average']
# ['mission', 'campus', 'open']
# ['university', 'fransisco', 'found']
# ['golden', 'large']
# ['northern', 'california', 'widely', 'circulate', 'newspaper']
# ['make', 'francisco', 'among', 'north', 'american', 'destination', 'convention', 'conference']
# ['manage', 'candlestick', 'point']
# ['crissy', 'field', 'airfield']
# ['young', 'museum', 'house', 'asian', 'museum']
# ['prompt', 'upgrade', 'building', 'code']
# ['swahili', 'dipthongs']
# ['swahili', 'bantu', 'language']
# ['uganda', 'swahili', 'require', 'subject', 'primary', 'school']
# ['swahili', 'swahili', 'language']
# ['swahili', 'speak', 'mozambique']
# ['swahili']
# ['class', 'swahili']
# ['germany', 'seize', 'tanganyika']
# ['saharan', 'indigenous', 'language', 'greatest', 'number', 'speaker']
# ['swedish', 'descendant', 'norse']
# ['swedish', 'perfect', 'participle', 'present', 'perfect', 'tense']
# ['swedish', 'speaker', 'report', 'canada']
# ['letters', 'basic', 'latin', 'alphabet']
# ['standard', 'common', 'language', 'become', 'available', 'swede']
# ['soviet', 'military', 'force', 'occupy', 'estonia']
# ['difference', 'english', 'swedish', 'pronoun']
# ['swedish', 'language', 'counterbalance', 'absence', 'case']
# ['taipei', 'valley']
# ['taipei', 'found', 'century']
# ['national', 'palace', 'museum', 'taipei']
# ['along', 'western', 'border']
# ['taipei']
# ['annual', 'festival', 'taipei']
# ['pacific', 'typhoon', 'season']
# ['s10_sets', 'shrine']
# ['taipei', 'produce']
# ['trumpet', 'musical', 'instrument', 'high', 'register', 'brass', 'family']
# ['trumpet', 'play', 'blowing', 'close']
# ['common', 'trumpet', 'trumpet']
# ['earliest', 'trumpet']
# ['trumpet', 'construct']
# ['small', 'trumpets', 'refer']
# ['trumpets', 'bright', 'sound']
# ['cornet', 'slightly', 'mellow', 'trumpet']
# ['make', 'trumpet', 'fully', 'chromatic']
# ['trumpet', 'player', 'heavily', 'guard']
# ['pocket', 'trumpets', 'compact', 'trumpets']
# ['dizzy', 'gillespie', 'famous', 'trumpeter']
# ['shape', 'trumpet']
# ['trumpet', 'first', 'allow', 'christian', 'church']
# ['trumpet', 'confuse', 'close', 'relative']
# ['augment', 'fourth', 'valve']
# ['maynard', 'ferguson', 'note', 'accurately']
# ['build']
# ['ottoman', 'script', 'replace', 'variant', 'latin', 'alphabet']
# ['definite', 'article', 'turkish', 'language']
# ['possible', 'alter', 'order', 'stress', 'importance', 'certain', 'phrase']
# ['official', 'language', 'turkey']
# ['turkish', 'language', 'association', 'found']
# ['significant', 'foreign', 'contributor', 'turkish', 'vocabulary']
# ['orkhon', 'inscription', 'build']
# ['result', 'introduction', 'turkish', 'alphabet']
# ['lewis', 'absolute', 'instead', 'nominative']
# ['people', 'speak', 'turkish', 'worldwide']
# ['turkish', 'syllable', 'usually', 'stress']
# ['spelling', 'turkish', 'phonetic']
# ['percentage', 'words', 'turkish', 'vocabulary', 'turkish', 'origin']
# ['event', 'turkish', 'language', 'association', 'establish']
# ['exception', 'rule', 'vowel', 'harmony', 'compound', 'words']
# ['pattern', 'vowel', 'harmony']
# ['group', 'noun']
# ['vietnamese', 'comparatively', 'large', 'number', 'vowel']
# ['vietnamese', 'mother', 'tongue', 'vietnamese', 'people']
# ['vietnamese', 'official', 'administrative', 'language', 'vietnam']
# ['vietnamese', 'influence', 'chinese']
# ['write', 'vietnamese', 'become', 'official', 'administrative', 'language']
# ['consonant', 'cluster']
# ['river', 'delta', 'traditionally']
# ['words', 'borrow', 'chinese']
# ['vietnam', 'independent', 'france']
# ['vietnamese', 'formally', 'write', 'using', 'chinese', 'writing', 'system']
# ['vietnamese', 'large', 'number', 'vowel']
# ['three', 'dialect', 'region', 'vietnamese']
# ['reunification', 'vietnam']
# ['tone', 'northern', 'variety']
# ['vietnamese', 'borrow', 'latin', 'greek']
# ['vietnamese', 'predominate', 'politically', 'century']
# ['northern', 'speaker', 'speak', 'southern', 'regional', 'dialect', 'southern', 'speaker', 'speak', 'northern', 'dialect']
# ['violin', 'strings']
# ['violin', 'support', 'shoulder']
# ['violin', 'shape', 'hourglass']
# ['strings', 'first']
# ['violin', 'call', 'informally']
# ['vitula']
# ['person', 'make', 'repair', 'violin', 'call']
# ['voice', 'violin', 'depend']
# ['violin', 'percussion', 'instrument']
# ['xylophone', 'musical', 'instrument']
# ['xylophone', 'associate', 'music', 'unite', 'state', 'century']
# ['likely', 'xylophone', 'reach', 'europe', 'crusade']
# ['xylophone', 'instrument', 'family']
# ['xylophone']
# ['version', 'xylophone', 'resonator']
# ['first', 'xylophone', 'vibraphone']
# ['golden', 'xylophone', 'first', 'usage', 'european', 'derive', 'orchestral']
# ['kelon', 'increase', 'decrease', 'quality', 'xylophone']
# ['different', 'species', 'zebra', 'interbreed']
# ['zebra', 'sleep', 'standing']
# ['plain', 'zebra', 'cross', 'mountain', 'zebra']
# ['species', 'zebra']
# ['zebra']
# ['zebra', 'hunt']
# ['area', 'grevy', 'zebra', 'inhabit']
# ['species', 'zebra', 'know', 'common', 'zebra']
# ['zebra', 'breed']

# %%
#here we are showcasing only for some random questions
import random
text_data = []
with open('QuestionForTopicDetection.csv') as f:
    for line in f:
        tokens = prepare_text_for_lda(line)
        if random.random() > .99:
            print(tokens)
            text_data.append(tokens)
# Out:
# ['adult', 'duck', 'flier']
# ['award', 'call', 'congressman', 'congressman']
# ['early', 'naturalist', 'distinguish', 'leopard', 'panther']
# ['millard', 'fillmore']
# ['challenge', 'establish', 'population', 'eurasian', 'otter']
# ['nickname', 'theodore', 'roosevelt', 'sister']
# ['grant', 'nothing', 'batte']
# ['netwon', 'investigate', 'refraction', 'light']
# ['hassan', 'massoudy', 'master', 'genre']
# ['butterfly', 'migratory']
# ['majority', 'loanword', 'korean']
# ['raise', 'extend', 'sound', 'chest', 'classical']
# ['english', 'language', 'often', 'speak', 'montreal']
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import gensim
from gensim.utils import simple_preprocess
import gensim.corpora as corpora
# Create Dictionary
dictionary = corpora.Dictionary(text_data)
# Create Corpus
texts = text_data
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# View
print(corpus[:1][0][:30])
# Out:
# [(0, 1)]
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from pprint import pprint
# number of topics
num_topics = 10
# Build LDA model
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics)
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING:gensim.models.ldamulticore:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# [(0,
#   '0.012*"giant" + 0.012*"panda" + 0.011*"population" + 0.011*"flute" + '
#   '0.010*"state" + 0.009*"unite" + 0.009*"president" + 0.007*"james" + '
#   '0.007*"first" + 0.006*"speak"'),
#  (1,
#   '0.016*"james" + 0.013*"monroe" + 0.012*"turtle" + 0.009*"language" + '
#   '0.008*"population" + 0.008*"volta" + 0.008*"jakarta" + 0.007*"piano" + '
#   '0.007*"penguin" + 0.007*"predator"'),
#  (2,
#   '0.020*"language" + 0.017*"call" + 0.014*"cymbal" + 0.012*"official" + '
#   '0.009*"turtle" + 0.008*"roosevelt" + 0.007*"common" + 0.007*"species" + '
#   '0.007*"large" + 0.007*"cello"'),
#  (3,
#   '0.011*"duck" + 0.008*"bury" + 0.008*"tesla" + 0.008*"volta" + '
#   '0.008*"faraday" + 0.007*"french" + 0.007*"vietnamese" + 0.007*"lincoln" + '
#   '0.007*"giraffe" + 0.006*"kangaroo"'),
#  (4,
#   '0.022*"otter" + 0.012*"turtle" + 0.010*"faraday" + 0.010*"found" + '
#   '0.009*"tesla" + 0.009*"beetle" + 0.007*"group" + 0.007*"ghana" + '
#   '0.007*"octopus" + 0.006*"people"'),
#  (5,
#   '0.034*"language" + 0.011*"arabic" + 0.009*"otter" + 0.008*"call" + '
#   '0.007*"speak" + 0.007*"adams" + 0.007*"cymbal" + 0.007*"official" + '
#   '0.007*"berlin" + 0.005*"flute"'),
#  (6,
#   '0.029*"large" + 0.010*"locate" + 0.008*"female" + 0.008*"otter" + '
#   '0.008*"avogadro" + 0.007*"language" + 0.007*"newton" + 0.007*"world" + '
#   '0.006*"montreal" + 0.006*"faraday"'),
#  (7,
#   '0.013*"newton" + 0.010*"piano" + 0.010*"liechtenstein" + 0.009*"first" + '
#   '0.008*"tesla" + 0.008*"words" + 0.007*"augustin" + 0.007*"charles" + '
#   '0.007*"coulomb" + 0.007*"coolidge"'),
#  (8,
#   '0.015*"leopard" + 0.012*"violin" + 0.009*"call" + 0.008*"indonesia" + '
#   '0.008*"faraday" + 0.006*"black" + 0.006*"piano" + 0.006*"nassau" + '
#   '0.005*"people" + 0.005*"airport"'),
#  (9,
#   '0.019*"elephant" + 0.014*"trumpet" + 0.011*"small" + 0.009*"university" + '
#   '0.009*"species" + 0.008*"musical" + 0.008*"water" + 0.006*"perfect" + '
#   '0.006*"turtle" + 0.006*"national"')]

# %%
import pyLDAvis.gensim
import pickle
import pyLDAvis
import os
# Visualize the topics
pyLDAvis.enable_notebook()
LDAvis_data_filepath = os.path.join('./results/ldavis_prepared_'+str(num_topics))

LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
with open(LDAvis_data_filepath, 'wb') as f:
    pickle.dump(LDAvis_prepared, f)
with open(LDAvis_data_filepath, 'rb') as f:
    LDAvis_prepared = pickle.load(f)
pyLDAvis.save_html(LDAvis_prepared, './results/ldavis_prepared_'+ str(num_topics) +'.html')
LDAvis_prepared
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py", line 426, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'pandas.core.indexes.numeric'
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# <ipython-input-121-24e3d1cb970f> in <cell line: 9>()
#       7 LDAvis_data_filepath = os.path.join('./results/ldavis_prepared_'+str(num_topics))
#       8
# ----> 9 LDAvis_prepared = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
#      10 with open(LDAvis_data_filepath, 'wb') as f:
#      11     pickle.dump(LDAvis_prepared, f)
#
# /usr/local/lib/python3.10/dist-packages/pyLDAvis/gensim.py in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#     121     """
#     122     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
# --> 123     return vis_prepare(**opts)
#
# /usr/local/lib/python3.10/dist-packages/pyLDAvis/_prepare.py in prepare(topic_term_dists, doc_topic_dists, doc_lengths, vocab, term_frequency, R, lambda_step, mds, n_jobs, plot_opts, sort_topics, start_index)
#     430     term_frequency = np.sum(term_topic_freq, axis=0)
#     431
# --> 432     topic_info = _topic_info(topic_term_dists, topic_proportion,
#     433                              term_frequency, term_topic_freq, vocab, lambda_step, R,
#     434                              n_jobs, start_index)
#
# /usr/local/lib/python3.10/dist-packages/pyLDAvis/_prepare.py in _topic_info(topic_term_dists, topic_proportion, term_frequency, term_topic_freq, vocab, lambda_step, R, n_jobs, start_index)
#     271         ])
#     272
# --> 273     top_terms = pd.concat(Parallel(n_jobs=n_jobs)
#     274                           (delayed(_find_relevance_chunks)(log_ttd, log_lift, R, ls)
#     275                           for ls in _job_chunks(lambda_seq, n_jobs)))
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1950         next(output)
#    1951
# -> 1952         return output if self.return_generator else list(output)
#    1953
#    1954     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1593
#    1594             with self._backend.retrieval_context():
# -> 1595                 yield from self._retrieve()
#    1596
#    1597         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1697             # worker traceback.
#    1698             if self._aborting:
# -> 1699                 self._raise_error_fast()
#    1700                 break
#    1701
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _raise_error_fast(self)
#    1732         # called directly or if the generator is gc'ed.
#    1733         if error_job is not None:
# -> 1734             error_job.get_result(self.timeout)
#    1735
#    1736     def _warn_exit_early(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in get_result(self, timeout)
#     734             # callback thread, and is stored internally. It's just waiting to
#     735             # be returned.
# --> 736             return self._return_or_raise()
#     737
#     738         # For other backends, the main thread needs to run the retrieval step.
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _return_or_raise(self)
#     752         try:
#     753             if self.status == TASK_ERROR:
# --> 754                 raise self._result
#     755             return self._result
#     756         finally:
#
# BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %%
import pickle

def is_picklable(obj):
    try:
        pickle.dumps(obj)
        return True
    except pickle.PicklingError:
        return False

print(is_picklable(dictionary))  # True
print(is_picklable(corpus))  # True
print(is_picklable(lda_model))  # True
# Out:
# True
# True
# True
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
